# %%
# pip install watermark
# %load_ext watermark
# %watermark -v -m -p numpy,scipy,pandas,matplotlib,sklearn -g 
#,statsmodels
# Out:
# CPython 3.6.7
# IPython 7.4.0
#
# numpy 1.16.2
# scipy 1.2.1
# pandas 0.24.2
# matplotlib 3.0.3
# sklearn 0.20.3
#
# compiler   : GCC 8.2.0
# system     : Linux
# release    : 4.9.93-boot2docker
# machine    : x86_64
# processor  : x86_64
# CPU cores  : 2
# interpreter: 64bit
# Git hash   :

# %%
from __future__ import division, print_function
import warnings
warnings.filterwarnings('ignore')
import os
import numpy as np
import pandas as pd
import math
import datetime
import re

# %%
COMPARATOR_AUTHOR = "Anton Tushev" 
COMPARATOR_VERSION = "v.10"
PATH_TO_DATA = '/notebooks/pinda/data'
#PATH_TO_STRUCG = '/notebooks/pinda/data/alcanc26_03_2019'
PATH_TO_STRUCG = '/notebooks/pinda/data/test'
FILE_NAME_DATA1 = 'TX04.csv'
#FILE_NAME_DATA1 = 'test.csv'
IGNORE_CHART = ['@SIMD']
#SD_RACK_NAMES = ['tx01','tx02','tx03','tx04']
SD_RACK_NAMES = ['tx04']
SKIP_EQUAL = True
SKIP_BLOCK_NEXST = True
SKIP_SIGNAL_NFND = True
SKIP_TYPE_STR = True
SKIP_CHART_NFND = True
COMPARATOR_README = "===================================================================================\r\n\
Comparator SimadynD <=> TDC software version: %s \r\nAuthor: %s \r\nComparation result made from %s \
StrucG folder \r\nDate and time: %s \r\nUse filters: \r\nXXXXXXXX - critical points \
\r\n!!!!!!!! - not critical errors \r\nFalse - difference in programs\r\nTrue - no difference in programs \
\r\n=====================\r\nCurren filters:\r\nSKIP_EQUAL:\t\t%s\r\nSKIP_BLOCK_NEXST:\t%s\r\nSKIP_SIGNAL_NFND:\t%s\r\n\
SKIP_TYPE_STR:\t\t%s\r\nSKIP_CHART_NFND:\t%s\r\n\
===================================================================================\r\n\
"%(COMPARATOR_VERSION,COMPARATOR_AUTHOR,PATH_TO_STRUCG,datetime.datetime.now(),SKIP_EQUAL,SKIP_BLOCK_NEXST, \
   SKIP_SIGNAL_NFND,SKIP_TYPE_STR,SKIP_CHART_NFND)
print(COMPARATOR_README)
# Out:
# ===================================================================================
# Comparator SimadynD <=> TDC software version: v.10
# Author: Anton Tushev
# Comparation result made from /notebooks/pinda/data/test StrucG folder
# Date and time: 2019-05-15 17:59:40.280570
# Use filters:
# XXXXXXXX - critical points
# !!!!!!!! - not critical errors
# False - difference in programs
# True - no difference in programs
# =====================
# Curren filters:
# SKIP_EQUAL:		True
# SKIP_BLOCK_NEXST:	True
# SKIP_SIGNAL_NFND:	True
# SKIP_TYPE_STR:		True
# SKIP_CHART_NFND:	True
# ===================================================================================

# %%
#Load TDC data
data_a1 = pd.read_csv(os.path.join(PATH_TO_DATA,FILE_NAME_DATA1),keep_default_na=False,na_values=[''], encoding="cp1251",sep=';',header=None)
data_a1 = data_a1[[0,1,3,5,11,13,28,29]]
data_a1.columns = ['rack_cpu','chart','block','signal','value','link','type','out']
data_a1 = pd.concat([data_a1, data_a1['rack_cpu'].str.split("\\",expand = True)[[0,1]]], axis=1) 
data_a1.columns = ['rack_cpu','chart','block','signal','value','link','type','out','rack','cpu']
data_a1["out"]= data_a1["out"].replace(("IN","OUT"),(0,1)).astype('bool') 
data_a1 = data_a1[~data_a1['chart'].isin(IGNORE_CHART)]
data_a1["block"] = data_a1["block"].astype(str)
print("Data types ",data_a1['type'].unique())
print("Charts ",data_a1['chart'].unique())
data_a1.head()
# Out:
# Data types  ['BOOL' 'REAL' 'SDTIME' 'WORD' 'INT' 'DINT' 'GLOBAL' 'STRING' 'DWORD'
#  'BYTE']
# Charts  ['ENCC_1' 'ENBRU1' 'ENBRI1' 'ENBEA1' 'BGT__1' '@SEND1' 'ENGAU1' 'ENGN11'
#  'ENMB_1' 'ENOSW1' 'ENGUA1' 'ENHDR1' 'ENIHW1' 'ENINS1' 'ENEXT1' 'ENENT1'
#  'ENSR_1' 'ENSPH1' 'ENSCD1' 'ENPIN1' 'ENPEL1' 'ENPAR1' 'ENISW1' 'ENLAP1'
#  'ENMA_1' 'ENMAN1' 'ENOHW1' 'ENSTR1' 'ENTEM1' 'ENTUR1' 'MESY_1' 'MONIM1'
#  'MONIW1' 'SERV_1' 'VISU_1' 'WPS__1' 'ENISW_MSU' 'ENDIA1' 'ENCRA1'
#  'ENCPT1' 'ENCPS1' 'ENCPP1' 'ENCPM1' 'ENCPH1' 'ENCPC1' 'ENCPA1' 'ENCOO1'
#  'ENMG_1' 'ENMC_1' 'ENMD_1' 'ENME_1' 'ENMF_1' '@SEND2' 'EXBAN2' 'EXBBH2'
#  'EXBBY2' 'EXBEA2' 'EXBW_2' 'EXBWA2' 'EXBWT2' 'EXCC_2' 'EXCRA2' 'EXCRM2'
#  'EXCUT2' 'EXDEF2' 'EXDIA2' 'EXFEL2' 'EXGAU2' 'EXGN12' 'EXGN22' 'EXIHW2'
#  'EXIR_2' 'EXIRP2' 'EXISW2' 'EXKNA2' 'EXLAP2' 'EXMAN2' 'EXMLR2' 'EXMLT2'
#  'EXOHW2' 'EXOSW2' 'EXPAR2' 'EXPUS2' 'EXREJ2' 'EXREL2' 'EXSC_2' 'EXSCA2'
#  'EXSCM2' 'EXSH12' 'EXSH22' 'EXSHJ2' 'EXSHT2' 'EXSML2' 'EXSR_2' 'EXSRC2'
#  'EXSRE2' 'EXSSC2' 'EXSSR2' 'EXSTR2' 'EXTB_2' 'EXTB12' 'EXTB22' 'EXTTB2'
#  'EXTUC2' 'EXWIP2' 'MESY_2' 'MONIM2' 'MONIW2' 'SERV_2' 'VISU_2' 'WPS__2']
#        rack_cpu   chart   block signal value               link  type    out  \
# 0  TX04\D01P01\  ENCC_1  ABLOKD     I1   NaN    ENCC_1\AND209.Q  BOOL  False
# 1  TX04\D01P01\  ENCC_1  ABLOKD     I2   NaN    ENCC_1\NOTBDW.Q  BOOL  False
# 2  TX04\D01P01\  ENCC_1  ABLOKD      Q     0   ENCC_1\XN1030.I4  BOOL   True
# 3  TX04\D01P01\  ENCC_1  ADD100     X1   NaN    ENCC_1\DIV001.Y  REAL  False
# 4  TX04\D01P01\  ENCC_1  ADD100     X2   NaN  ENCC_1\CTB003.Y15  REAL  False
#
#    rack     cpu
# 0  TX04  D01P01
# 1  TX04  D01P01
# 2  TX04  D01P01
# 3  TX04  D01P01
# 4  TX04  D01P01

# %%
#Generate Simadyn chart structure
def sd_get_chart_list(PATH_TO_STRUCG=PATH_TO_STRUCG,SD_RACK_NAMES=SD_RACK_NAMES):
    #filter chart files
    n = re.compile("^(((?!old).)*).((cfp)|(ofp))$")
    file_list=[] 
    file_list = {rack_name:[item for item in os.listdir(os.path.join(PATH_TO_STRUCG,rack_name)) \
        # chart file names filter conditions
        if os.path.isfile(os.path.join(PATH_TO_STRUCG,rack_name, item)) and (n.search(item)) and len(item)<11 \
        ] for rack_name in SD_RACK_NAMES}
    file_list_filtered = dict(file_list)
    for i in file_list:
        for k in file_list[i]:
            chart_name = k.split('.')[0]
            if "%s.cfp"%chart_name in file_list[i]:
                try:
                    file_list_filtered[i].remove("%s.ofp"%chart_name)
                except ValueError:
                    pass  # do nothing
    out_dict = dict()
    for i in file_list_filtered:
        out_dict[i] = dict()
        for k in file_list_filtered[i]:
            out_dict[i][k.split('.')[0]]=os.path.join(PATH_TO_STRUCG,i,k)
    if out_dict:
        return out_dict
    else:
        return -1

sd_chart_list = sd_get_chart_list() 

##output => #sd_chart_list {"tx03":{'chrt_name':file_addrs}}

# %%
#n = re.search("^(((?!old).)*).((cfp)|(ofp))$", 'pray1___20131208.cfp')
test_txt = []
test_txt.append(" 325	I1  B1 < VIHW09.Q15&")
test_txt.append('  81	IS  V2 < $VISW17')
test_txt.append(" 163	Q1  B1 > ,'Man__CPS'            \"MAINTENANCE COIL PREP STATION\"")
test_txt.append(' 115	I1  B1 < VIHW17.Q2&')
test_txt.append(' 519	X1  N2 < @TYP=V2,0HFFFF')
test_txt.append(' 520	X2  N2 < @TYP=V2,LB2.QS&')
test_txt.append(' 527	QS  V2 > $VGAU02                "Diagnose 2nd direction"')
test_txt.append(' 528	Q   B1 > ')
test_txt.append("  31	AD  NK = D02_I1.X8C")
test_txt.append("  32	DM  B1 - 1")
test_txt.append("  22	AR  NS - 'B1G1X1'")
test_txt.append("  21	CTS CR - D0300A")
test_txt.append("1151	T1  NS - '@F@85@ EN QFC Coil P. Shear Tab. Air Float'")
test_txt.append("1199	X1  N2 < 0%")
test_txt.append("1200	X2  N2 < SEND07.QS")
test_txt.append("1201	I   B1 < EN_MES.Q,'EN_MES'&")
test_txt.append(" 566	LZU NF < #10000[ms],'RunTime '  \"Run time monitoring\"")
test_txt.append("1207	X2  N2 < 18.298%                \"18,3 representa 3000 kg\"")
test_txt.append("1283	X2  NF < #0")
test_txt.append("1304	X2  NF < #26,'GRAUS'")
test_txt.append(" 905	X2  NF < #100.0000000E3")
test_txt.append("1074	Y   NF > @TYP=TF,$PTTI_A,'PTTI_AUT'&")
test_txt.append("1073	X   NF < @TYP=TF,10[S]")
test_txt.append("2983	X2  NF < #530.0000000E-3,'m'")
test_txt.append(" 439	FBU NF < #500[ms],'Feedback'    \"Feedback monitoring\"")
test_txt.append(" 494	I   B1 < STG641.Q")
test_txt.append(" 495	Y   N2 > @TYP=V2")
test_txt.append("  17	X1  NF < $XIHW05,SCAL=1[m]")
test_txt.append(" 374	T   TF <  3           [s]")
test_txt.append(" 169	T   TF <            2[s ]")
test_txt.append("2946	OR  V2 < 0B00000000 00000000")
test_txt.append(" 108	X05 NF < #2500.0[V/(m/s)],'ky'  \"Scaling factor for control output\"&")

test_txt2 = " 439	FBU NF < #500[ms],'Feedback'    \"Feedback monitoring\""


#m = re.compile(r"^\s*\d+\s+(\w+)\s+(\w+)\s+([<>])\s+(@TYP=(..),)?([^@\"',&]+)([,\"'&]|$)", )
m = re.compile(r"""
        ^\s*\d+\s+ #string number
        (\w+)\s+   #signal name 
        (\w+)\s+   #signal type 
        ([<>=-])\s+  #signal delimiter 
        (@TYP=(..),?)? #singal type
        (   #value
        ([a-zA-Z0-9_.]+)|  #can be connection to other block
        ([$%\[\]/()a-zA-Z0-9_.#-]+)|  #can be virtual connection or value
        ([0-9.]+\s*\[.*\])|  #can be time with spaces
        ([0-9B]+\s+[0-9]+)|  #can be hex in bit representation
        ('.*') #can be text
        )? #end of value
        (,)? #divider
        ('.*')? #link comment
        (,.*)? #some comment
        (\s+".*")? #signal comment
        (&)? #check next string
        ($) #end of string
        """, re.X)
k = re.compile(r"^\s*\d+\s+(\w+)\s+(\w+)\s+([<>=-])")

for a in test_txt:
    n = m.search(a)
    print(a)
    print(n.group(1),n.group(2),n.group(3),n.group(5),n.group(6),n.group(13))
    #print(n)
    
#n = m.search(test_txt2)
#print("OUT:",n.group(1),n.group(2),n.group(3),n.group(6),n.group(13))

#for a in test_txt:
#    n = k.search(a)
#    print(n)

#for a in test_txt:
#    n = k.search(a)
#    print(n)
# Out:
#  325	I1  B1 < VIHW09.Q15&
# I1 B1 < None VIHW09.Q15 None
#   81	IS  V2 < $VISW17
# IS V2 < None $VISW17 None
#  163	Q1  B1 > ,'Man__CPS'            "MAINTENANCE COIL PREP STATION"
# Q1 B1 > None None 'Man__CPS'
#  115	I1  B1 < VIHW17.Q2&
# I1 B1 < None VIHW17.Q2 None
#  519	X1  N2 < @TYP=V2,0HFFFF
# X1 N2 < V2 0HFFFF None
#  520	X2  N2 < @TYP=V2,LB2.QS&
# X2 N2 < V2 LB2.QS None
#  527	QS  V2 > $VGAU02                "Diagnose 2nd direction"
# QS V2 > None $VGAU02 None
#  528	Q   B1 >
# Q B1 > None None None
#   31	AD  NK = D02_I1.X8C
# AD NK = None D02_I1.X8C None
#   32	DM  B1 - 1
# DM B1 - None 1 None
#   22	AR  NS - 'B1G1X1'
# AR NS - None 'B1G1X1' None
#   21	CTS CR - D0300A
# CTS CR - None D0300A None
# 1151	T1  NS - '@F@85@ EN QFC Coil P. Shear Tab. Air Float'
# T1 NS - None '@F@85@ EN QFC Coil P. Shear Tab. Air Float' None
# 1199	X1  N2 < 0%
# X1 N2 < None 0% None
# 1200	X2  N2 < SEND07.QS
# X2 N2 < None SEND07.QS None
# 1201	I   B1 < EN_MES.Q,'EN_MES'&
# I B1 < None EN_MES.Q 'EN_MES'
#  566	LZU NF < #10000[ms],'RunTime '  "Run time monitoring"
# LZU NF < None #10000[ms] 'RunTime '
# 1207	X2  N2 < 18.298%                "18,3 representa 3000 kg"
# X2 N2 < None 18.298% None
# 1283	X2  NF < #0
# X2 NF < None #0 None
# 1304	X2  NF < #26,'GRAUS'
# X2 NF < None #26 'GRAUS'
#  905	X2  NF < #100.0000000E3
# X2 NF < None #100.0000000E3 None
# 1074	Y   NF > @TYP=TF,$PTTI_A,'PTTI_AUT'&
# Y NF > TF $PTTI_A 'PTTI_AUT'
# 1073	X   NF < @TYP=TF,10[S]
# X NF < TF 10[S] None
# 2983	X2  NF < #530.0000000E-3,'m'
# X2 NF < None #530.0000000E-3 'm'
#  439	FBU NF < #500[ms],'Feedback'    "Feedback monitoring"
# FBU NF < None #500[ms] 'Feedback'
#  494	I   B1 < STG641.Q
# I B1 < None STG641.Q None
#  495	Y   N2 > @TYP=V2
# Y N2 > V2 None None
#   17	X1  NF < $XIHW05,SCAL=1[m]
# X1 NF < None $XIHW05 None
#  374	T   TF <  3           [s]
# T TF < None 3           [s] None
#  169	T   TF <            2[s ]
# T TF < None 2[s ] None
# 2946	OR  V2 < 0B00000000 00000000
# OR V2 < None 0B00000000 00000000 None
#  108	X05 NF < #2500.0[V/(m/s)],'ky'  "Scaling factor for control output"&
# X05 NF < None #2500.0[V/(m/s)] 'ky'

# %%
test_txt = []
test_txt.append("   &		(SEND01.I9)")
test_txt.append('   &		(KA1014.I2,KA1015.I2)')
k = re.compile(r"^\s*&+\s+\((.*)\)\s*$")
for a in test_txt:
    n = k.search(a)
    print(n.group(1))
    #print(n)
# Out:
# SEND01.I9
# KA1014.I2,KA1015.I2

# %%
def sd_open_chart(chart_addr):
    try:
        with open(chart_addr) as f:
            lines = [line.rstrip('\n') for line in f]
    except EnvironmentError: # parent of IOError, OSError *and* WindowsError where available
        #print('ERROR File not exists!')
        return -1
    return lines

#generate chart mapping: line {block name:[block line begin, block line end]}
def sd_get_chart_map(inp_line):
    #b = re.compile(r"\d+ ? +: [a-zA-Z0-9_.]+\s*,\s*POS=")
    #b = re.compile(r".*:.*POS=")
    b = re.compile(r"^\s*\d+ ?([a-zA-Z0-9_]+) +: [a-zA-Z0-9_.]+\s*,\s*POS=")
    el = re.compile(r'^ *\d+\s+[+]')
    block_list = []
    mark_bloc = False
    out_dict = dict()
    line_counter = 0
    for k in inp_line:
        b_s = b.search(k)
        if b_s :
            mark_bloc = True
            curr_block_name = b_s.group(1)
            block_list.append(curr_block_name)
            mark_bloc_line_beg = line_counter
        elif el.search(k):
            if mark_bloc:
                mark_bloc = False
                out_dict[curr_block_name] = [mark_bloc_line_beg,line_counter]
        line_counter = line_counter+1        
    #print(len(block_list))
    if(out_dict):
        return out_dict
    else:
        return -1

#check if line is signal or link
def sd_check_line_signal(line):
    sf = re.compile(r"^\s*\d+\s+(\w+)\s+(\w+)\s+([<>=-])")
    sa = re.compile(r"^\s*&+\s+(\(.*\))\s*$")
    if sf.search(line):
        out = 1 #signal
    elif sa.search(line):
        out = 2 #link
    else:
        out = 0 #nothing
    return out

#extract data from signal line
def sd_get_line_data(line): 
    m = re.compile(r"""
        ^\s*\d+\s+ #string number
        (\w+)\s+   #signal name 
        (\w+)\s+   #signal type 
        ([<>=-])\s+  #signal delimiter 
        (@TYP=(..),?)? #singal type
        (   #value
        ([a-zA-Z0-9_.]+)|  #can be connection to other block
        ([$%\[\]/()a-zA-Z0-9_.#-]+)|  #can be virtual connection or value
        ([0-9.]+\s*\[.*\])|  #can be time with spaces
        ([0-9B]+\s+[0-9]+)|  #can be hex in bit representation
        ('.*') #can be text
        )? #end of value
        (,)? #divider
        ('.*')? #link comment
        (,.*)? #some comment
        (\s+".*")? #signal comment
        (&)? #check next string
        ($) #end of string
        """, re.X)
    #print(line)
    n = m.search(line)
                 #name      type       dir        type_conv  value      
    return list([n.group(1),n.group(2),n.group(3),n.group(5),n.group(6)])

def sd_get_line_link(line): 
    m = re.compile(r"^\s*&+\s+\((.*)\)\s*$")
    n = m.search(line)     
    return n.group(1)  

def sd_get_block_data(lines):
    NAME,TYPE_BASE,INOUT,TYPE_CONV,VALUE = 0,1,2,3,4
    mark_signal_row_name = None
    mark_signal_row_data = list([[],[]]) #[[signal data],[links]]
    mark_block_row_data = []
    count = 0;
    for l in lines:
        line_check_result = sd_check_line_signal(l)
        if line_check_result:
            if line_check_result==1:  
                #if found a signal line
                count = count+1
                #add previous signal to preparation table
                if mark_signal_row_name:
                    #print("Old name:",mark_signal_row_name)
                    mark_block_row_data.append(mark_signal_row_data)
                    mark_signal_row_data = list([[],[]]) #reset buffer table
                #name,type,dir,type_conv,more
                mark_signal_row_data[0] = sd_get_line_data(l)
                mark_signal_row_name = mark_signal_row_data[0][NAME]
                #print(mark_signal_row_name)
            elif line_check_result==2:
                #if found a link line
                mark_signal_row_data[1].extend(sd_get_line_link(l).split(','))
            #print(mark_signal_row_data)            
        else:
            pass #skip string
    #Add last signal to preparation storage
    mark_block_row_data.append(mark_signal_row_data)
    return mark_block_row_data
    
def sd_conv_block_data_to_df(block_data):
    #list element of row signal data:[[NAME,TYPE_BASE,INOUT,TYPE_CONV,VALUE],[links]]
    block_df = pd.DataFrame([[j for j in k[0]]+[k[1]] for k in block_data])
    return block_df

# %%
def sd_build_data_s1(sd_chart_list):
    data_df = pd.DataFrame(None, index=[], columns=range(8))
    for i in sd_chart_list:
        for (k,v) in sd_chart_list[i].items():
            
            chart_lines = sd_open_chart(v)
            chart_mapping = sd_get_chart_map(chart_lines)
            print("Parsing '%s' chart with %s functions"%(k,len(chart_mapping)))
            for block_map in chart_mapping:
                #print(block_map,chart_mapping[block_map])
                block_lines = chart_lines[chart_mapping[block_map][0]:chart_mapping[block_map][1]]
                block_data = sd_get_block_data(block_lines)
                block_data_df = sd_conv_block_data_to_df(block_data)
                block_data_df[6] = k
                block_data_df[7] = block_map
                data_df = data_df.append(block_data_df, ignore_index = True) 
    return data_df



data_s1 = sd_build_data_s1(sd_chart_list)
data_s1.columns = ['signal','type_base','inout','type_conv','value','link','chart','block']
data_s1["block"] = data_s1["block"].astype(str)
len(data_s1)
data_s1
# Out:
# Parsing 'bgt__1' chart with 11 functions
# Parsing 'encc_1' chart with 586 functions
# Parsing 'engau1' chart with 51 functions
# Parsing 'enma_1' chart with 371 functions
# Parsing 'enmb_1' chart with 433 functions
# Parsing 'enmc_1' chart with 397 functions
# Parsing 'enmd_1' chart with 402 functions
# Parsing 'enme_1' chart with 413 functions
# Parsing 'enmf_1' chart with 372 functions
# Parsing 'enmg_1' chart with 201 functions
# Parsing 'ensr_1' chart with 137 functions
# Parsing 'mesy_1' chart with 74 functions
# Parsing 'serv_1' chart with 12 functions
# Parsing 'visu_1' chart with 177 functions
# Parsing 'wps__1' chart with 12 functions
#       signal type_base inout type_conv       value                  link  \
# 0        CTS        CR     -      None      D0400A                    []
# 1         AT        NS     -      None  'EXEXCCMD'                    []
# 2         AR        NS     -      None  'EXEXCACK'                    []
# 3        ADT        NS     -      None  'EXEXCDAT'                    []
# 4        CCV        V4     <      None     VCC.CVP                    []
# 5        YTS        O2     >      None        None                    []
# 6        YTZ        O2     >      None        None                    []
# 7        QTS        B1     >      None        None           [BGTS01.I2]
# 8        CTS        CR     -      None      D01_P1                    []
# 9         AT        NS     -      None  'ENENCCMD'                    []
# 10        AR        NS     -      None  'ENENCACK'                    []
# 11       ADT        NS     -      None  'ENENCDAT'                    []
# 12       CCV        V4     <      None     VCC.CVP                    []
# 13       YTS        O2     >      None        None           [VCOK10.X1]
# 14       YTZ        O2     >      None        None                    []
# 15       QTS        B1     >      None        None           [BGTS01.I5]
# 16       CTS        CR     -      None      D2303B                    []
# 17        AT        NS     -      None  'ENDMCSEN'                    []
# 18        AR        NS     -      None  'ENDMCREC'                    []
# 19        NC        O2     -      None           2                    []
# 20       CVP        V4     >      None        None  [CIC2.CCV, CIC1.CCV]
# 21       YTS        O2     >      None        None           [VCOK20.X1]
# 22       YTZ        O2     >      None        None                    []
# 23       YTT        O2     >      None        None                    []
# 24       YTR        O2     >      None        None                    []
# 25       QTS        B1     >      None        None           [BGTS01.I1]
# 26       QKF        B1     >      None        None                    []
# 27       GLO        V4     >      None        None                    []
# 28        X1        N2     <        O2    CIC1.YTS                    []
# 29        X2        N2     <        O2           0                    []
# ...      ...       ...   ...       ...         ...                   ...
# 22759    I14        B1     <      None           0                    []
# 22760    I15        B1     <      None           0                    []
# 22761    I16        B1     <      None           0                    []
# 22762     QS        V2     >      None        None              [USF.IS]
# 22763     IS        V2     <      None      BSC.QS                    []
# 22764      I        B1     <      None           0                    []
# 22765      Y        V4     >      None        None              [THEN.X]
# 22766    RN1        I2     >      None        None                    []
# 22767    RN2        I2     >      None        None                    []
# 22768    QKF        B1     >      None        None                    []
# 22769      I        B1     <      None           1                    []
# 22770      Q        B1     >      None        None           [EQT010.I1]
# 22771     I1        B1     <      None    EQT000.Q                    []
# 22772     I2        B1     <      None           1                    []
# 22773      Q        B1     >      None        None           [EQT020.I1]
# 22774     I1        B1     <      None    EQT010.Q                    []
# 22775     I2        B1     <      None     $BCSCDM                    []
# 22776     I3        B1     <      None           1                    []
# 22777     I4        B1     <      None           1                    []
# 22778      Q        B1     >      None        None            [EQT030.I]
# 22779      I        B1     <      None    EQT020.Q                    []
# 22780      T        TF     <      None      3[min]                    []
# 22781      Q        B1     >      None        None          [EQT040.IAC]
# 22782     NO        O2     <      None           4                    []
# 22783    IAC        B1     <      None    EQT030.Q                    []
# 22784     Y1        V2     >      None        None                    []
# 22785     Y2        V2     >      None        None                    []
# 22786     Y3        V2     >      None        None                    []
# 22787     Y4        V2     >      None        None                    []
# 22788     QF        B1     >      None        None                    []
#
#         chart   block
# 0      bgt__1    CIC2
# 1      bgt__1    CIC2
# 2      bgt__1    CIC2
# 3      bgt__1    CIC2
# 4      bgt__1    CIC2
# 5      bgt__1    CIC2
# 6      bgt__1    CIC2
# 7      bgt__1    CIC2
# 8      bgt__1    CIC1
# 9      bgt__1    CIC1
# 10     bgt__1    CIC1
# 11     bgt__1    CIC1
# 12     bgt__1    CIC1
# 13     bgt__1    CIC1
# 14     bgt__1    CIC1
# 15     bgt__1    CIC1
# 16     bgt__1     VCC
# 17     bgt__1     VCC
# 18     bgt__1     VCC
# 19     bgt__1     VCC
# 20     bgt__1     VCC
# 21     bgt__1     VCC
# 22     bgt__1     VCC
# 23     bgt__1     VCC
# 24     bgt__1     VCC
# 25     bgt__1     VCC
# 26     bgt__1     VCC
# 27     bgt__1     VCC
# 28     bgt__1  VCOK10
# 29     bgt__1  VCOK10
# ...       ...     ...
# 22759  wps__1     BSC
# 22760  wps__1     BSC
# 22761  wps__1     BSC
# 22762  wps__1     BSC
# 22763  wps__1     USF
# 22764  wps__1     END
# 22765  wps__1     END
# 22766  wps__1     SWP
# 22767  wps__1     SWP
# 22768  wps__1     SWP
# 22769  wps__1  EQT000
# 22770  wps__1  EQT000
# 22771  wps__1  EQT010
# 22772  wps__1  EQT010
# 22773  wps__1  EQT010
# 22774  wps__1  EQT020
# 22775  wps__1  EQT020
# 22776  wps__1  EQT020
# 22777  wps__1  EQT020
# 22778  wps__1  EQT020
# 22779  wps__1  EQT030
# 22780  wps__1  EQT030
# 22781  wps__1  EQT030
# 22782  wps__1  EQT040
# 22783  wps__1  EQT040
# 22784  wps__1  EQT040
# 22785  wps__1  EQT040
# 22786  wps__1  EQT040
# 22787  wps__1  EQT040
# 22788  wps__1  EQT040
#
# [22789 rows x 8 columns]

# %%
def sd_rect_data_s1(data_df):
    def filter_func_output(x):
        if x:
            con_check = re.compile(r'(\S+[.]\D+)')
            res = con_check.search(x)
            if res:
                return True
            else:
                return False
        else:
            return False
        return 
    data_df_out = pd.DataFrame(data_df)
    data_df_out.loc[data_df_out['value'].apply(filter_func_output),'link'] = data_df_out.loc[data_df_out['value'].apply(filter_func_output),'value']
    return data_df_out



out_df = sd_rect_data_s1(data_s1)
out_df
# Out:
#       signal type_base inout type_conv       value                  link  \
# 0        CTS        CR     -      None      D0400A                    []
# 1         AT        NS     -      None  'EXEXCCMD'                    []
# 2         AR        NS     -      None  'EXEXCACK'                    []
# 3        ADT        NS     -      None  'EXEXCDAT'                    []
# 4        CCV        V4     <      None     VCC.CVP               VCC.CVP
# 5        YTS        O2     >      None        None                    []
# 6        YTZ        O2     >      None        None                    []
# 7        QTS        B1     >      None        None           [BGTS01.I2]
# 8        CTS        CR     -      None      D01_P1                    []
# 9         AT        NS     -      None  'ENENCCMD'                    []
# 10        AR        NS     -      None  'ENENCACK'                    []
# 11       ADT        NS     -      None  'ENENCDAT'                    []
# 12       CCV        V4     <      None     VCC.CVP               VCC.CVP
# 13       YTS        O2     >      None        None           [VCOK10.X1]
# 14       YTZ        O2     >      None        None                    []
# 15       QTS        B1     >      None        None           [BGTS01.I5]
# 16       CTS        CR     -      None      D2303B                    []
# 17        AT        NS     -      None  'ENDMCSEN'                    []
# 18        AR        NS     -      None  'ENDMCREC'                    []
# 19        NC        O2     -      None           2                    []
# 20       CVP        V4     >      None        None  [CIC2.CCV, CIC1.CCV]
# 21       YTS        O2     >      None        None           [VCOK20.X1]
# 22       YTZ        O2     >      None        None                    []
# 23       YTT        O2     >      None        None                    []
# 24       YTR        O2     >      None        None                    []
# 25       QTS        B1     >      None        None           [BGTS01.I1]
# 26       QKF        B1     >      None        None                    []
# 27       GLO        V4     >      None        None                    []
# 28        X1        N2     <        O2    CIC1.YTS              CIC1.YTS
# 29        X2        N2     <        O2           0                    []
# ...      ...       ...   ...       ...         ...                   ...
# 22759    I14        B1     <      None           0                    []
# 22760    I15        B1     <      None           0                    []
# 22761    I16        B1     <      None           0                    []
# 22762     QS        V2     >      None        None              [USF.IS]
# 22763     IS        V2     <      None      BSC.QS                BSC.QS
# 22764      I        B1     <      None           0                    []
# 22765      Y        V4     >      None        None              [THEN.X]
# 22766    RN1        I2     >      None        None                    []
# 22767    RN2        I2     >      None        None                    []
# 22768    QKF        B1     >      None        None                    []
# 22769      I        B1     <      None           1                    []
# 22770      Q        B1     >      None        None           [EQT010.I1]
# 22771     I1        B1     <      None    EQT000.Q              EQT000.Q
# 22772     I2        B1     <      None           1                    []
# 22773      Q        B1     >      None        None           [EQT020.I1]
# 22774     I1        B1     <      None    EQT010.Q              EQT010.Q
# 22775     I2        B1     <      None     $BCSCDM                    []
# 22776     I3        B1     <      None           1                    []
# 22777     I4        B1     <      None           1                    []
# 22778      Q        B1     >      None        None            [EQT030.I]
# 22779      I        B1     <      None    EQT020.Q              EQT020.Q
# 22780      T        TF     <      None      3[min]                    []
# 22781      Q        B1     >      None        None          [EQT040.IAC]
# 22782     NO        O2     <      None           4                    []
# 22783    IAC        B1     <      None    EQT030.Q              EQT030.Q
# 22784     Y1        V2     >      None        None                    []
# 22785     Y2        V2     >      None        None                    []
# 22786     Y3        V2     >      None        None                    []
# 22787     Y4        V2     >      None        None                    []
# 22788     QF        B1     >      None        None                    []
#
#         chart   block
# 0      bgt__1    CIC2
# 1      bgt__1    CIC2
# 2      bgt__1    CIC2
# 3      bgt__1    CIC2
# 4      bgt__1    CIC2
# 5      bgt__1    CIC2
# 6      bgt__1    CIC2
# 7      bgt__1    CIC2
# 8      bgt__1    CIC1
# 9      bgt__1    CIC1
# 10     bgt__1    CIC1
# 11     bgt__1    CIC1
# 12     bgt__1    CIC1
# 13     bgt__1    CIC1
# 14     bgt__1    CIC1
# 15     bgt__1    CIC1
# 16     bgt__1     VCC
# 17     bgt__1     VCC
# 18     bgt__1     VCC
# 19     bgt__1     VCC
# 20     bgt__1     VCC
# 21     bgt__1     VCC
# 22     bgt__1     VCC
# 23     bgt__1     VCC
# 24     bgt__1     VCC
# 25     bgt__1     VCC
# 26     bgt__1     VCC
# 27     bgt__1     VCC
# 28     bgt__1  VCOK10
# 29     bgt__1  VCOK10
# ...       ...     ...
# 22759  wps__1     BSC
# 22760  wps__1     BSC
# 22761  wps__1     BSC
# 22762  wps__1     BSC
# 22763  wps__1     USF
# 22764  wps__1     END
# 22765  wps__1     END
# 22766  wps__1     SWP
# 22767  wps__1     SWP
# 22768  wps__1     SWP
# 22769  wps__1  EQT000
# 22770  wps__1  EQT000
# 22771  wps__1  EQT010
# 22772  wps__1  EQT010
# 22773  wps__1  EQT010
# 22774  wps__1  EQT020
# 22775  wps__1  EQT020
# 22776  wps__1  EQT020
# 22777  wps__1  EQT020
# 22778  wps__1  EQT020
# 22779  wps__1  EQT030
# 22780  wps__1  EQT030
# 22781  wps__1  EQT030
# 22782  wps__1  EQT040
# 22783  wps__1  EQT040
# 22784  wps__1  EQT040
# 22785  wps__1  EQT040
# 22786  wps__1  EQT040
# 22787  wps__1  EQT040
# 22788  wps__1  EQT040
#
# [22789 rows x 8 columns]

# %%
bool(re.search(r'(\S+[.]\D+)|(^\$\S+)',"1.11Q"))
# Out:
# False

# %%
str.upper("asd")
# Out:
# 'ASD'

# %%
#Comparator
for i, j in data_s1[data_s1['inout']=="<"].iterrows():
        if(len(j['link'])!=0):
            filter_result = data_a1[(data_a1['block']==str(j['block']).upper())\
                          &(data_a1['chart']==str(j['chart']).upper())\
                          &(data_a1['signal']==str(j['signal']).upper())]['link'].to_string(index =False)
            sd_link = str(str.upper(j['chart']+"\\"+str.upper(j['link']))).strip()
            if filter_result.strip() != sd_link:
                print(filter_result)
                print(sd_link)
                print(str.upper(j['chart']),str.upper(j['block']),str.upper(j['signal']),str.upper(j['link']))
# Out:
# Series([], )
# ENCC_1\SETAB2.Q
# ENCC_1 BLK36 I1 SETAB2.Q
# Series([], )
# ENCC_1\BLK20.Q
# ENCC_1 BLK36 I2 BLK20.Q
#  NaN
# ENCC_1\PHOTO.QU
# ENCC_1 TURINT I4 PHOTO.QU
# Series([], )
# ENCC_1\XS_CCT.Y
# ENCC_1 COPOP2 X XS_CCT.Y
# Series([], )
# ENCC_1\ANCOV3.Q
# ENCC_1 SETAB2 S ANCOV3.Q
# Series([], )
# ENCC_1\ORCOV2.Q
# ENCC_1 SETAB2 R ORCOV2.Q
# Series([], )
# ENCC_1\COPOP2.QL
# ENCC_1 ANCOV3 I1 COPOP2.QL
# Series([], )
# ENCC_1\COMVEL.QU
# ENCC_1 ANCOV3 I2 COMVEL.QU
# Series([], )
# ENCC_1\COPOPO.QL
# ENCC_1 ORCOV2 I1 COPOPO.QL
# Series([], )
# ENCC_1\COMVE2.QL
# ENCC_1 ORCOV2 I2 COMVE2.QL
# Series([], )
# ENCC_1\STW12.Y
# ENCC_1 MASKE1 IS1 STW12.Y
# Series([], )
# ENCC_1\XTG611.Y
# ENCC_1 XTG624 IS1 XTG611.Y
# Series([], )
# ENCC_1\XTG681.Y
# ENCC_1 XTG691 IS1 XTG681.Y
# Series([], )
# ENGAU1\STG611.Y
# ENGAU1 STG624 IS1 STG611.Y
# Series([], )
# ENGAU1\STG681.Y
# ENGAU1 STG691 IS1 STG681.Y
# Series([], )
# ENMA_1\STG611.Y
# ENMA_1 STG624 IS1 STG611.Y
# Series([], )
# ENMA_1\STG681.Y
# ENMA_1 STG691 IS1 STG681.Y
# Series([], )
# ENMA_1\XTG611.Y
# ENMA_1 XTG624 IS1 XTG611.Y
# Series([], )
# ENMA_1\XTG681.Y
# ENMA_1 XTG691 IS1 XTG681.Y
# Series([], )
# ENMA_1\YTG611.Y
# ENMA_1 YTG624 IS1 YTG611.Y
# Series([], )
# ENMA_1\YTG681.Y
# ENMA_1 YTG691 IS1 YTG681.Y
# Series([], )
# ENMA_1\ZTG611.Y
# ENMA_1 ZTG624 IS1 ZTG611.Y
# Series([], )
# ENMA_1\ZTG681.Y
# ENMA_1 ZTG691 IS1 ZTG681.Y
# Series([], )
# ENMB_1\STG611.Y
# ENMB_1 STG624 IS1 STG611.Y
# Series([], )
# ENMB_1\STG681.Y
# ENMB_1 STG691 IS1 STG681.Y
# Series([], )
# ENMB_1\XTG611.Y
# ENMB_1 XTG624 IS1 XTG611.Y
# Series([], )
# ENMB_1\XTG681.Y
# ENMB_1 XTG691 IS1 XTG681.Y
# Series([], )
# ENMB_1\YTG611.Y
# ENMB_1 YTG624 IS1 YTG611.Y
# Series([], )
# ENMB_1\YTG681.Y
# ENMB_1 YTG691 IS1 YTG681.Y
# Series([], )
# ENMB_1\ZTG611.Y
# ENMB_1 ZTG624 IS1 ZTG611.Y
# Series([], )
# ENMB_1\ZTG681.Y
# ENMB_1 ZTG691 IS1 ZTG681.Y
# Series([], )
# ENMC_1\STG611.Y
# ENMC_1 STG624 IS1 STG611.Y
# Series([], )
# ENMC_1\STG681.Y
# ENMC_1 STG691 IS1 STG681.Y
# Series([], )
# ENMC_1\XTG611.Y
# ENMC_1 XTG624 IS1 XTG611.Y
# Series([], )
# ENMC_1\XTG681.Y
# ENMC_1 XTG691 IS1 XTG681.Y
# Series([], )
# ENMC_1\YTG611.Y
# ENMC_1 YTG624 IS1 YTG611.Y
# Series([], )
# ENMC_1\YTG681.Y
# ENMC_1 YTG691 IS1 YTG681.Y
# Series([], )
# ENMC_1\ZTG611.Y
# ENMC_1 ZTG624 IS1 ZTG611.Y
# Series([], )
# ENMC_1\ZTG681.Y
# ENMC_1 ZTG691 IS1 ZTG681.Y
# Series([], )
# ENMD_1\STG611.Y
# ENMD_1 STG624 IS1 STG611.Y
# Series([], )
# ENMD_1\STG681.Y
# ENMD_1 STG691 IS1 STG681.Y
# Series([], )
# ENMD_1\XTG611.Y
# ENMD_1 XTG624 IS1 XTG611.Y
# Series([], )
# ENMD_1\XTG681.Y
# ENMD_1 XTG691 IS1 XTG681.Y
# Series([], )
# ENMD_1\YTG611.Y
# ENMD_1 YTG624 IS1 YTG611.Y
# Series([], )
# ENMD_1\YTG681.Y
# ENMD_1 YTG691 IS1 YTG681.Y
# Series([], )
# ENMD_1\ZTG611.Y
# ENMD_1 ZTG624 IS1 ZTG611.Y
# Series([], )
# ENMD_1\ZTG681.Y
# ENMD_1 ZTG691 IS1 ZTG681.Y
# Series([], )
# ENME_1\STG611.Y
# ENME_1 STG624 IS1 STG611.Y
# Series([], )
# ENME_1\STG681.Y
# ENME_1 STG691 IS1 STG681.Y
# Series([], )
# ENME_1\XTG611.Y
# ENME_1 XTG624 IS1 XTG611.Y
# Series([], )
# ENME_1\XTG681.Y
# ENME_1 XTG691 IS1 XTG681.Y
# Series([], )
# ENME_1\YTG611.Y
# ENME_1 YTG624 IS1 YTG611.Y
# Series([], )
# ENME_1\YTG681.Y
# ENME_1 YTG691 IS1 YTG681.Y
# Series([], )
# ENME_1\ZTG611.Y
# ENME_1 ZTG624 IS1 ZTG611.Y
# Series([], )
# ENME_1\ZTG681.Y
# ENME_1 ZTG691 IS1 ZTG681.Y
# Series([], )
# ENMF_1\STG611.Y
# ENMF_1 STG624 IS1 STG611.Y
# Series([], )
# ENMF_1\STG681.Y
# ENMF_1 STG691 IS1 STG681.Y
# Series([], )
# ENMF_1\XTG611.Y
# ENMF_1 XTG624 IS1 XTG611.Y
# Series([], )
# ENMF_1\XTG681.Y
# ENMF_1 XTG691 IS1 XTG681.Y
# Series([], )
# ENMF_1\YTG611.Y
# ENMF_1 YTG624 IS1 YTG611.Y
# Series([], )
# ENMF_1\YTG681.Y
# ENMF_1 YTG691 IS1 YTG681.Y
# Series([], )
# ENMF_1\ZTG611.Y
# ENMF_1 ZTG624 IS1 ZTG611.Y
# Series([], )
# ENMF_1\ZTG681.Y
# ENMF_1 ZTG691 IS1 ZTG681.Y
# Series([], )
# ENMG_1\STG611.Y
# ENMG_1 STG624 IS1 STG611.Y
# Series([], )
# ENMG_1\STG681.Y
# ENMG_1 STG691 IS1 STG681.Y
# Series([], )
# ENMG_1\XTG611.Y
# ENMG_1 XTG624 IS1 XTG611.Y
# Series([], )
# ENMG_1\XTG681.Y
# ENMG_1 XTG691 IS1 XTG681.Y
# Series([], )
# ENSR_1\STG611.Y
# ENSR_1 STG624 IS1 STG611.Y
# Series([], )
# ENSR_1\STG681.Y
# ENSR_1 STG691 IS1 STG681.Y
# Series([], )
# ENSR_1\XTG611.Y
# ENSR_1 XTG624 IS1 XTG611.Y
# Series([], )
# ENSR_1\XTG681.Y
# ENSR_1 XTG691 IS1 XTG681.Y
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# <ipython-input-385-ac6f005647a9> in <module>
#       4             filter_result = data_a1[(data_a1['block']==str(j['block']).upper())\
#       5                           &(data_a1['chart']==str(j['chart']).upper())\
# ----> 6                           &(data_a1['signal']==str(j['signal']).upper())]['link'].to_string(index =False)
#       7             sd_link = str(str.upper(j['chart']+"\\"+str.upper(j['link']))).strip()
#       8             if filter_result.strip() != sd_link:
#
# /usr/local/lib/python3.6/dist-packages/pandas/core/ops.py in wrapper(self, other, axis)
#    1764
#    1765             with np.errstate(all='ignore'):
# -> 1766                 res = na_op(values, other)
#    1767             if is_scalar(res):
#    1768                 raise TypeError('Could not compare {typ} type with Series'
#
# /usr/local/lib/python3.6/dist-packages/pandas/core/ops.py in na_op(x, y)
#    1623
#    1624         if is_object_dtype(x.dtype):
# -> 1625             result = _comp_method_OBJECT_ARRAY(op, x, y)
#    1626
#    1627         elif is_datetimelike_v_numeric(x, y):
#
# /usr/local/lib/python3.6/dist-packages/pandas/core/ops.py in _comp_method_OBJECT_ARRAY(op, x, y)
#    1601         result = libops.vec_compare(x, y, op)
#    1602     else:
# -> 1603         result = libops.scalar_compare(x, y, op)
#    1604     return result
#    1605
#
# KeyboardInterrupt:
